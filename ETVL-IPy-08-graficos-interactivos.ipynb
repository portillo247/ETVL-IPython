# %% [markdown]
# # Procesos ETVL usando IPython -- 08 -- Gráficos Interactivos
# Notas de clase sobre la extracción, transformación, visualización y carga de datos usando IPython

# %% [markdown]
# **Juan David Velásquez Henao**
# jdvelasq@unal.edu.co
# Universidad Nacional de Colombia, Sede Medellín
# Facultad de Minas
# Medellín, Colombia
#
# [Licencia](https://github.com/jdvelasq/ETVL-IPython/blob/master/LICENCIA.txt)
# [Readme](https://github.com/jdvelasq/ETVL-IPython/blob/master/Readme.md)

# %% [markdown]
# **Software utilizado**
#
# > Este es un documento interactivo escrito como un notebook de [Jupyter](http://jupyter.org), en el cual se presenta un tutorial sobre la extracción, transformación, visualización y carga de datos usando **Python** en el contexto de la ciencia de los datos. Los notebooks de Jupyter permiten incoporar simultáneamente código, texto, gráficos y ecuaciones. El código presentado en este notebook puede ejecutarse en los sistemas operativos Linux y OS X.
#
# > Haga click [aquí](https://github.com/jdvelasq/guias-de-instalacion) para obtener instrucciones detalladas sobre como instalar Jupyter en Windows y Mac OS X.
#
# > Haga clic [aquí](http://nbviewer.jupyter.org/github/jdvelasq/ETVL-IPython/blob/master/ETVL-IPy-08-graficos-interactivos.ipynb) para ver la última versión de este documento en nbviewer.
#
# > Descargue la última versión de este documento a su disco duro; luego, carguelo y ejecutelo en línea en [Try Jupyter!](https://try.jupyter.org)

# %% [markdown]
# #### Contenido

# %% [markdown]
# >

# %% [markdown]
# # Plot.ly

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# > [plotly](https://plot.ly)

# %% [markdown]
# `plotly`  es una plataforma web colaborativa para la visualización y el análisis de datos.
#
#
# Para poder instalar la librería debe ejecutar el siguiente comando:

# %%
# %%sh
# pip install plotly
# Out:
# Requirement already satisfied (use --upgrade to upgrade): plotly in /Users/jdvelasq/anaconda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): requests in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from plotly)
# Requirement already satisfied (use --upgrade to upgrade): six in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from plotly)
# Requirement already satisfied (use --upgrade to upgrade): pytz in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from plotly)

# %% [markdown]
# El sitio web ofrece ejemplos y material sobre el uso de la librería.
#
# Ejecute el siguiente ejemplo para verificar que la librería funciona correctamente.

# %%
# importa la librería
import plotly
plotly.__version__  # imprime la versión instalada de plotly
# Out:
# '1.12.7'

# %%
# importa las librerias para graficación
import plotly.plotly as py  
import plotly.tools as tls

# %% [markdown]
# Para poder usar plotly, es necesario crear una cuenta gratuita en plot.ly. Una vez creada la cuenta, se debe obtener el api_key personal.
#
# En el siguiente paso, se procede al loggin en plotly.

# %%
# py.sign_in('your_username','your_api_key')
py.sign_in('jdvelasq','lal1fddnot')

# %%
# se generan datos para producir la gráfica.
x1 = [1, 2, 3, 5, 6]
y1 = [1, 4.5, 7, 24, 38]
trace1 = dict(x=x1, y=y1)
data = [trace1]

# %%
# Se hace el gráfico.
py.plot(data, filename='myplot')
# Out:
# 'https://plot.ly/~jdvelasq/2'

# %% [markdown]
# El último comando genera la visualización de los datos en el sitio web de plotly. En el navegador de internet debe aparecer una pestaña como la siguiente:
#
# <img src="images/plotly_user.png" width="750" >

# %% [markdown]
# ---
# # Bokeh

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Bokeh es una librería para graficación desarrollada por [Continuum Analytics](https://www.continuum.io). El tutorial de Bokeh puede consultarse en el sitio oficial de la herramienta, cuyo vínculo está suministrado en la bibiografía.
#
#
# En este tutorial se presenta un gráfico en Bokeh que tiene como fin probar que la librería está correctamente instalada.

# %%
# El primer paso consiste en importar las librerias en Jupyter.
import numpy as np
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id
ceb596","#97ac96","#9a7796","#7d6d96","#d1c596","#4f5396","#ec6696","#722796","#cdb596","#793396","#df3896","#d36b96","#59ca96","#ac3f96","#cf5296","#d5b396","#b67b96","#ce6e96","#df7796","#61b696","#4f2d96","#5fac96","#c63f96","#82e096","#f87c96","#4abe96","#b6ab96","#673096","#4c2b96","#8d8296","#867596","#e32e96","#c0a596","#f66f96","#4d4896","#e4de96","#52db96","#8f8f96","#ef6096","#a5d096","#d24e96","#623e96","#43db96","#b18996","#84ce96","#e22396","#5e7096","#af7b96","#e42996","#d3ab96","#809b96","#b7d096","#937096","#d24d96","#da5796","#d8ca96","#70dc96","#68d596","#9d2196","#d88896","#63d096","#ecc196","#5e9296","#e68b96","#f48696","#aa8f96","#cd9e96","#602e96","#7bb096","#46df96","#af4296","#b8d496","#e0d796","#359396","#bf6296","#5bd996","#7e4296","#6a7396","#bb7996","#c0e496","#efc096","#cdc296","#3b7c96","#64d196","#873b96","#f15b96","#776796","#9a1f96","#4b9596","#a25c96","#d78f96","#86b396","#496d96","#73c396","#d69196","#8e5796","#df6796","#3f2596","#854696","#d6c196","#511f96","#b68596","#4f2b96","#7ec796","#4c9996","#b45096","#82b196","#8ac696","#d66696","#7e5096","#6fa396","#59ae96","#e72096","#4d9396","#486f96","#38e396","#4f2c96","#8f7896","#e12f96","#578696","#755796","#5b9a96","#ceb796","#f94996","#b85b96","#666096","#c82d96","#e5ac96","#9d5e96","#c4a196","#7e9e96","#33bb96","#95e296","#ec9696","#f7b996","#548196","#67d096" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %% [markdown]
# ---
# # Seaborn

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# > [Seaborn](https://web.stanford.edu/~mwaskom/software/seaborn/) by Michael Waskom.

# %% [markdown]
# Seaborn es una librería para la visualización de datos estadísticos desarrollada en matplotlib por M. Waskom. El sitio web indicado en la bibliografía contiene información detallada incluyendo la [guía de instalación](https://web.stanford.edu/~mwaskom/software/seaborn/installing.html#installing), [notas introductorias](https://web.stanford.edu/~mwaskom/software/seaborn/introduction.html#introduction), un [tutorial](https://web.stanford.edu/~mwaskom/software/seaborn/tutorial.html#tutorial) y el [manual de referencia](https://web.stanford.edu/~mwaskom/software/seaborn/api.html#api-ref).
#
# A continuación se realiza un gráfico (del tutorial) en Jupyter para verificar que `seaborn` funciona correctamente.

# %%
# %%sh
# conda install seaborn
# Out:
# Fetching package metadata .......
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/jdvelasq/anaconda:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.7.1              |           py35_0         282 KB
#
# The following NEW packages will be INSTALLED:
#
#     seaborn: 0.7.1-py35_0
#
# Proceed ([y]/n)?
# Fetching packages ...
# seaborn-0.7.1- 100% |###############################| Time: 0:00:01 232.70 kB/s
# Extracting packages ...
# [      COMPLETE      ]|##################################################| 100%
# Linking packages ...
# [      COMPLETE      ]|##################################################| 100%
# Using Anaconda Cloud api site https://api.anaconda.org

# %%
# Se procede igual que cuando se realizan gráficos en matplotlib.
import matplotlib.pyplot as plt
import numpy as np

# para que los gráficos se hagan en línea.
# %matplotlib inline    

# se generan los puntos aleatorios.
x = np.random.normal(size=100)

# %%
# se importa la librería.
import seaborn as sns
sns.set_style("white") # se quita la malla (grid).
sns.distplot(x)        # distribution plot (histograma)
sns.despine(offset=10) # se modifican los ejes

# %% [markdown]
# ---
# # Lightning

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# > [Lightning](https://nbviewer.jupyter.org/github/lightning-viz/lightning-example-notebooks/blob/master/index.ipynb)

# %% [markdown]
# Lighting es otra librería gráfica que puede usarse en varios lenguajes incluyendo Python.
#
# Para poder instalar la librería debe ejecutar los siguientes comandos:

# %%
# %%sh
# pip install lightning-python
# Out:
# Requirement already satisfied (use --upgrade to upgrade): lightning-python in /Users/jdvelasq/anaconda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): numpy in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): pytest in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): six in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): setuptools in /Users/jdvelasq/anaconda/lib/python3.5/site-packages/setuptools-20.3-py3.5.egg (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): jinja2 in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): requests in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): matplotlib in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): py>=1.4.29 in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from pytest->lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): MarkupSafe in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from jinja2->lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from matplotlib->lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): pytz in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from matplotlib->lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): cycler in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from matplotlib->lightning-python)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing!=2.0.4,>=1.5.6 in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from matplotlib->lightning-python)

# %%
import lightning 

from numpy import random, asarray, sqrt, arctan2, pi, clip
from seaborn import color_palette
from sklearn import datasets
from colorsys import hsv_to_rgb

# %%
from lightning import Lightning
lgn = Lightning()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-9f2d16dd5ce7> in <module>()
# ----> 1 from lightning import Lightning
#       2 lgn = Lightning()
#
# ImportError: cannot import name 'Lightning'

# %%
lgn = lightning.Lightning(ipython=True, host='http://public.lightning-viz.org')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e6da2bfaaeb0> in <module>()
# ----> 1 lgn = lightning.Lightning(ipython=True, host='http://public.lightning-viz.org')
#
# AttributeError: module 'lightning' has no attribute 'Lightning'

# %%
n = 100
x = random.randn(n)
y = random.randn(n)
c = [asarray(color_palette('Blues', 100)[random.choice(range(100))])*255 for i in range(n)]
a = random.rand(n)
s = random.rand(n)*15+8
lgn.scatter(x, y, color=c, alpha=a, size=s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e608129e12d4> in <module>()
#       1 n = 100
# ----> 2 x = random.randn(n)
#       3 y = random.randn(n)
#       4 c = [asarray(color_palette('Blues', 100)[random.choice(range(100))])*255 for i in range(n)]
#       5 a = random.rand(n)
#
# NameError: name 'random' is not defined

# %% [markdown]
# ---
# # Vincent: A Python to Vega Translator

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# > [Vicent](https://github.com/wrobstory/vincent)

# %% [markdown]
# Permite hacer gráficos en Python usando Javascript.

# %%
# %%sh
# pip install vincent
# Out:
# Collecting vincent
#   Downloading vincent-0.4.4.tar.gz
# Requirement already satisfied (use --upgrade to upgrade): pandas in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from vincent)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil>=2 in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from pandas->vincent)
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from pandas->vincent)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.7.0 in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from pandas->vincent)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in /Users/jdvelasq/anaconda/lib/python3.5/site-packages (from python-dateutil>=2->pandas->vincent)
# Building wheels for collected packages: vincent
#   Running setup.py bdist_wheel for vincent: started
#   Running setup.py bdist_wheel for vincent: finished with status 'done'
#   Stored in directory: /Users/jdvelasq/Library/Caches/pip/wheels/82/be/21/1bdaa169bcfc2a7381c1aff07ad1eb43ee6bc24f51b912f492
# Successfully built vincent
# Installing collected packages: vincent
# Successfully installed vincent-0.4.4

# %%
# datos para la gráfica
import pandas as pd
import random
import pandas.io.data as web
all_data = {}
for ticker in ['AAPL', 'GOOG', 'IBM', 'YHOO', 'MSFT']:
    all_data[ticker] = web.get_data_yahoo(ticker, '1/1/2010', '1/1/2013')
price = pd.DataFrame({tic: data['Adj Close']
                      for tic, data in all_data.items()})

# %%
import vincent
vincent.core.initialize_notebook()

line = vincent.Line(price[['GOOG', 'AAPL']])
line.axis_titles(x='Date', y='Price')
line.legend(title='GOOG vs AAPL')
line.display()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <div id="v
 1265173200000, "val": 270.140309}, {"col": "AAPL", "idx": 1265173200000, "val": 26.057159}, {"col": "GOOG", "idx": 1265259600000, "val": 263.127321}, {"col": "AAPL", "idx": 1265259600000, "val": 25.118093}, {"col": "GOOG", "idx": 1265346000000, "val": 265.380075}, {"col": "AAPL", "idx": 1265346000000, "val": 25.564084}, {"col": "GOOG", "idx": 1265605200000, "val": 266.468996}, {"col": "AAPL", "idx": 1265605200000, "val": 25.388826}, {"col": "GOOG", "idx": 1265691600000, "val": 267.95252200000004}, {"col": "AAPL", "idx": 1265691600000, "val": 25.659561}, {"col": "GOOG", "idx": 1265778000000, "val": 266.95849599999997}, {"col": "AAPL", "idx": 1265778000000, "val": 25.519617}, {"col": "GOOG", "idx": 1265864400000, "val": 267.932539}, {"col": "AAPL", "idx": 1265864400000, "val": 25.983917}, {"col": "GOOG", "idx": 1265950800000, "val": 266.29417}, {"col": "AAPL", "idx": 1265950800000, "val": 26.207567}, {"col": "GOOG", "idx": 1266296400000, "val": 270.380071}, {"col": "AAPL", "idx": 1266296400000, "val": 26.602551000000002}, {"col": "GOOG", "idx": 1266382800000, "val": 268.836627}, {"col": "AAPL", "idx": 1266382800000, "val": 26.491381}, {"col": "GOOG", "idx": 1266469200000, "val": 271.339119}, {"col": "AAPL", "idx": 1266469200000, "val": 26.541079999999997}, {"col": "GOOG", "idx": 1266555600000, "val": 270.11035}, {"col": "AAPL", "idx": 1266555600000, "val" ...

# %% [markdown]
# ---
# # Veusz -- A scientific plotting package

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# > [Veusz](http://home.gna.org/veusz/)

# %% [markdown]
# Es una herramienta escrita en Python para la visualización interactiva de datos.
#
# <img src="images/veusz_mac_mainwin.png" width="750" >

# %% [markdown]
# ---
# # PyQtGraph -- Scientific Graphics and GUI Library for Python

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Sitio web: http://www.pyqtgraph.org

# %% [markdown]
# ---
# # PhosphorJS
# Sitio web: https://phosphorjs.github.io

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# ---
# # Networkx

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Sitio web: https://networkx.github.io/download.html
#
# Instalación:
# ```
# conda install networkx
# ```

# %% [markdown]
# ---
# # MPLD3: Bringing Matplotlib to the Browser

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Sitio web: http://mpld3.github.io
#
# Instalación:

# %%
# %%sh
# conda install mpld3
# Out:
# Fetching package metadata ...........
# Solving package specifications: ..........
#
# # All requested packages already installed.
# # packages in environment at /Users/jdvelasq/anaconda:
# #
# mpld3                     0.2                      py35_0
# Using Anaconda Cloud api site https://api.anaconda.org

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import mpld3
mpld3.enable_notebook()

# %%
from mpld3 import plugins
fig, ax = plt.subplots()
points = ax.scatter(np.random.rand(40), np.random.rand(40),
                    s=300, alpha=0.3)

labels = ["Point {0}".format(i) for i in range(40)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %% [markdown]
# ---
# # VisPy

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Sitio web: http://vispy.org/index.html

# %% [markdown]
# ---
# # PyNGL & PyNIO

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Sitio web: https://www.pyngl.ucar.edu/Examples/index.shtml

# %% [markdown]
# ---
# # PyQwt plots data with Numerical Python and PyQt

# %% [markdown]
# [Contenido](#Contenido)

# %% [markdown]
# Sitio web: http://pyqwt.sourceforge.net

# %% [markdown]
# ---
